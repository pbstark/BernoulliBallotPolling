# %% [markdown]
# # Table of sampling rates
#
# Table 1 in the paper. Workload for Bernoulli sampling RLA, using a risk limit of 5%. Simulations assume that the reported margins were correct.

# %%
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
import math
import numpy as np
import scipy as sp
from scipy.stats import binom, hypergeom
import pandas as pd
from geometric_skipping import geometric_skipping
from sprt import ballot_polling_sprt
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/importlib/_bootstrap.py:321: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %%
def compute_unconditional_power(Nw, Nl, popsize, pi, alpha, reps=10000, seed=12345678900987654321):
    '''
    Estimate unconditional power of the test: sample at rate pi, then run the SPRT on that sample.
    Calculations assume that the reported margin is correct and that the nuisance parameter 
    (total number of ballots for either w or l) is known.
        
    Nw = total number of votes reported for w,
    Nl = total number of votes reported for l,
    popsize = total population size,
    pi = the sampling probability,
    alpha = the type I error rate,
    reps = number of simulations
    '''
    pvalues = np.zeros(reps)
    population = np.array([0]*Nl + [1]*Nw + [np.nan]*(popsize-Nw-Nl)) # Population of ballots (truth)
    np.random.shuffle(population)
    for i in range(reps):
#        sam = geometric_skipping(population, pi, seed=seed*i) # slow because the SHA256 generator is slow.
        n = binom.rvs(popsize, pi)
        sam = np.random.choice(population, size=n, replace=False)
        res = ballot_polling_sprt(sample=sam, popsize=popsize, alpha=alpha, Vw=Nw, Vl=Nl, number_invalid=popsize-Nw-Nl)
        pvalues[i] = res['pvalue']
    power = np.mean(pvalues <= alpha)
    return power

# %% [markdown]
# ## Power table for $\alpha = 0.05$
#
# Finding the sampling rate $p$ to achieve power $80\%, 90\%, 99\%$ for varying population sizes and vote margins.

# %%
def estimate_powers(popsize, margin, pi_step=0.2, pi_tol=2, lo_pi=0, reps=10000):
        """
        Estimate the sampling rates p1, p2, p3 to attain power 80%, 90%, and 99%,
        assuming only ballots for w and l were cast.
        
        popsize = integer population size
        margin = percent margin between w and l
        pi_step = initial linear search step size
        pi_tol = precision for estimating sampling rates. 
                 e.g. if pi_tol = 2, then only sampling rates 1%, 2%, ... are possible.
                 if pi_tol = 3, then sampling rates 1.1%, 1.2%, ... are possible.
        lo_pi = lowest sampling rate to try
        hi_pi = highest sampling rate to try
        """
        
        print('Running N='+str(popsize)+", margin="+str(margin))
        m = margin
        Nw = int(0.5*popsize*(m+1))
        Nl = popsize - Nw
        p1 = 1
        p2 = 1
        p3 = 1
        x = compute_unconditional_power(Nw=Nw, Nl=Nl, popsize=popsize, pi=lo_pi, alpha=alpha, reps=reps)
        
        lo80_pi = lo_pi
        lo90_pi = lo_pi
        hi_pi = lo_pi
        
        # Step out by pi_step sampling rates until getting at least 99% power
        while x < 0.99:
            if x < 0.9:
                lo90_pi = hi_pi
            if x < 0.8:
                lo80_pi = hi_pi
            hi_pi += pi_step
            x_lo = x
            if hi_pi > 1:
                break
            x = compute_unconditional_power(Nw=Nw, Nl=Nl, popsize=popsize, pi=hi_pi, alpha=alpha, reps=reps)
            print("trying pi=", hi_pi, ", power is ", x)
            if np.isnan(x):
                continue
        
        def bisect(lo_pi, hi_pi, desired_power):
            xmid = 1
            while xmid > desired_power and round(hi_pi-lo_pi, pi_tol)>0:
                mid_pi = round((lo_pi + hi_pi)/2, pi_tol)
                if mid_pi == lo_pi or mid_pi == hi_pi:
                    break
                x_mid = compute_unconditional_power(Nw=Nw, Nl=Nl, popsize=popsize, pi=mid_pi, alpha=alpha, reps=reps)
                print("trying pi=", mid_pi, ", power is ", x_mid)
                if x_mid > desired_power:
                    x = x_mid
                    hi_pi = mid_pi
                else:
                    x_lo = x_mid
                    lo_pi = mid_pi
            return hi_pi
        
        # Bisection method between pi and pi-pi_step to find where power is 99%
        p3 = bisect(hi_pi - pi_step, hi_pi, 0.99)
        
        # Bisection method between p3 (99% power) and lo90_pi to find where power is 90%
        p2 = bisect(lo90_pi, p3, 0.9)
        
        # Bisection method between p2 (90% power) and lo80_pi to find where power is 80%
        p1 = bisect(lo80_pi, p2, 0.8)

        return(p1, p2, p3)

# %%
simTable = pd.DataFrame(columns=("Pop size", "Margin", "p for 80% power","p for 90% power", "p for 99% power")
                       )

alpha = 0.05
N = [10**5, 10**6, 10**7]
power = [0.8, 0.9, 0.99]
margin = [0.01, 0.02, 0.05, 0.1, 0.2]
reps = 10000


# N = 10**5
res = estimate_powers(popsize=10**5, margin=0.01, pi_step=0.2, pi_tol=2, lo_pi=0.4, reps=reps)
simTable.loc[len(simTable)] = 10**5, 0.01, res[0], res[1], res[2]
for m in margin[1:]:
    res = estimate_powers(popsize=10**5, margin=m, pi_step=0.2, pi_tol=2, lo_pi=0, reps=reps)
    simTable.loc[len(simTable)] = 10**5, m, res[0], res[1], res[2]
    
# N = 10**6
for m in margin:
    res = estimate_powers(popsize=10**6, margin=m, pi_step=0.05, pi_tol=3, lo_pi=0, reps=reps)
    simTable.loc[len(simTable)] = 10**6, m, res[0], res[1], res[2]

# N = 10**7
for m in margin:
    res = estimate_powers(popsize=10**7, margin=m, pi_step=0.01, pi_tol=4, lo_pi=0, reps=reps)
    simTable.loc[len(simTable)] = 10**7, m, res[0], res[1], res[2]
# Out:
# Running N=100000, margin=0.01
# trying pi= 0.6000000000000001 , power is  0.8718
# trying pi= 0.8 , power is  0.9967
# trying pi= 0.7 , power is  0.967
# trying pi= 0.75 , power is  0.9857
# trying pi= 0.78 , power is  0.9931
# trying pi= 0.77 , power is  0.9917
# trying pi= 0.76 , power is  0.9858
# trying pi= 0.69 , power is  0.9566
# trying pi= 0.65 , power is  0.9311
# trying pi= 0.62 , power is  0.9002
# trying pi= 0.61 , power is  0.8885
# trying pi= 0.51 , power is  0.7528
# trying pi= 0.56 , power is  0.8305
# trying pi= 0.54 , power is  0.7945
# trying pi= 0.55 , power is  0.8169
# Running N=100000, margin=0.02
# trying pi= 0.2 , power is  0.7398
# trying pi= 0.4 , power is  0.974
# trying pi= 0.6000000000000001 , power is  0.9996
# trying pi= 0.5 , power is  0.9953
# trying pi= 0.45 , power is  0.9899
# trying pi= 0.47 , power is  0.9933
# trying pi= 0.46 , power is  0.9915
# trying pi= 0.33 , power is  0.9397
# trying pi= 0.27 , power is  0.8716
# trying pi= 0.3 , power is  0.906
# trying pi= 0.29 , power is  0.897
# trying pi= 0.25 , power is  0.8436
# trying pi= 0.23 , power is  0.8095
# trying pi= 0.22 , power is  0.7849
# Running N=100000, margin=0.05
# trying pi= 0.2 , power is  1.0
# trying pi= 0.1 , power is  0.9809
# trying pi= 0.15 , power is  0.9971
# trying pi= 0.12 , power is  0.991
# trying pi= 0.11 , power is  0.9861
# trying pi= 0.06 , power is  0.8909
# trying pi= 0.09 , power is  0.9728
# trying pi= 0.07 , power is  0.9302
# trying pi= 0.04 , power is  0.7522
# trying pi= 0.06 , power is  0.8888
# trying pi= 0.05 , power is  0.8388
# Running N=100000, margin=0.1
# trying pi= 0.2 , power is  1.0
# trying pi= 0.1 , power is  1.0
# trying pi= 0.05 , power is  0.9996
# trying pi= 0.03 , power is  0.9876
# trying pi= 0.04 , power is  0.9967
# trying pi= 0.02 , power is  0.9459
# trying pi= 0.01 , power is  0.7375
# trying pi= 0.01 , power is  0.7455
# Running N=100000, margin=0.2
# trying pi= 0.2 , power is  1.0
# trying pi= 0.1 , power is  1.0
# trying pi= 0.05 , power is  1.0
# trying pi= 0.03 , power is  1.0
# trying pi= 0.01 , power is  0.9969
# Running N=1000000, margin=0.01
# trying pi= 0.05 , power is  0.4356
# trying pi= 0.1 , power is  0.7826
# trying pi= 0.15000000000000002 , power is  0.9152
# trying pi= 0.2 , power is  0.9722
# trying pi= 0.25 , power is  0.9913
# trying pi= 0.225 , power is  0.984
# trying pi= 0.237 , power is  0.9856
# trying pi= 0.243 , power is  0.9902
# trying pi= 0.24 , power is  0.9886
# trying pi= 0.241 , power is  0.9888
# trying pi= 0.242 , power is  0.9904
# trying pi= 0.171 , power is  0.9453
# trying pi= 0.136 , power is  0.8917
# trying pi= 0.154 , power is  0.9288
# trying pi= 0.145 , power is  0.9137
# trying pi= 0.141 , power is  0.8998
# trying pi= 0.143 , power is  0.9035
# trying pi= 0.142 , power is  0.9047
# trying pi= 0.121 , power is  0.8539
# trying pi= 0.111 , power is  0.8233
# trying pi= 0.106 , power is  0.8009
# trying pi= 0.103 , power is  0.7842
# trying pi= 0.104 , power is  0.8024
# Running N=1000000, margin=0.02
# trying pi= 0.05 , power is  0.9508
# trying pi= 0.1 , power is  0.9983
# trying pi= 0.075 , power is  0.9902
# trying pi= 0.062 , power is  0.9777
# trying pi= 0.069 , power is  0.9836
# trying pi= 0.072 , power is  0.9872
# trying pi= 0.073 , power is  0.9881
# trying pi= 0.074 , power is  0.9896
# trying pi= 0.037 , power is  0.8831
# trying pi= 0.056 , power is  0.9645
# trying pi= 0.046 , power is  0.932
# trying pi= 0.041 , power is  0.9036
# trying pi= 0.039 , power is  0.8955
# trying pi= 0.04 , power is  0.9035
# trying pi= 0.02 , power is  0.6535
# trying pi= 0.03 , power is  0.8208
# trying pi= 0.025 , power is  0.7497
# trying pi= 0.028 , power is  0.7989
# trying pi= 0.029 , power is  0.8163
# Running N=1000000, margin=0.05
# trying pi= 0.05 , power is  1.0
# trying pi= 0.025 , power is  1.0
# trying pi= 0.013 , power is  0.9911
# trying pi= 0.006 , power is  0.8717
# trying pi= 0.009 , power is  0.9599
# trying pi= 0.011 , power is  0.9818
# trying pi= 0.012 , power is  0.9861
# trying pi= 0.006 , power is  0.8771
# trying pi= 0.009 , power is  0.9599
# trying pi= 0.007 , power is  0.9188
# trying pi= 0.004 , power is  0.7429
# trying pi= 0.005 , power is  0.8292
# Running N=1000000, margin=0.1
# trying pi= 0.05 , power is  1.0
# trying pi= 0.025 , power is  1.0
# trying pi= 0.013 , power is  1.0
# trying pi= 0.006 , power is  0.9991
# trying pi= 0.003 , power is  0.9859
# trying pi= 0.005 , power is  0.9998
# trying pi= 0.004 , power is  0.996
# trying pi= 0.002 , power is  0.946
# trying pi= 0.001 , power is  0.7468
# trying pi= 0.001 , power is  0.7348
# Running N=1000000, margin=0.2
# trying pi= 0.05 , power is  1.0
# trying pi= 0.025 , power is  1.0
# trying pi= 0.013 , power is  1.0
# trying pi= 0.006 , power is  1.0
# trying pi= 0.003 , power is  1.0
# trying pi= 0.002 , power is  1.0
# trying pi= 0.001 , power is  0.9958
# Running N=10000000, margin=0.01
# trying pi= 0.01 , power is  0.7333
# trying pi= 0.02 , power is  0.95
# trying pi= 0.03 , power is  0.9876
# trying pi= 0.04 , power is  0.9976
# trying pi= 0.035 , power is  0.9937
# trying pi= 0.0325 , power is  0.9917
# trying pi= 0.0312 , power is  0.9912
# trying pi= 0.0306 , power is  0.9894
# trying pi= 0.0309 , power is  0.989
# trying pi= 0.0311 , power is  0.9906
# trying pi= 0.031 , power is  0.9891
# trying pi= 0.0205 , power is  0.9506
# trying pi= 0.0152 , power is  0.8852
# trying pi= 0.0179 , power is  0.9218
# trying pi= 0.0165 , power is  0.9
# trying pi= 0.0172 , power is  0.914
# trying pi= 0.0169 , power is  0.9086
# trying pi= 0.0167 , power is  0.9112
# trying pi= 0.0166 , power is  0.9052
# trying pi= 0.0133 , power is  0.844
# trying pi= 0.0117 , power is  0.8034
# trying pi= 0.0109 , power is  0.7755
# trying pi= 0.0113 , power is  0.7893
# trying pi= 0.0115 , power is  0.8014
# trying pi= 0.0114 , power is  0.7892
# Running N=10000000, margin=0.02
# trying pi= 0.01 , power is  0.9972
# trying pi= 0.005 , power is  0.9463
# trying pi= 0.0075 , power is  0.9875
# trying pi= 0.0088 , power is  0.9941
# trying pi= 0.0082 , power is  0.9888
# trying pi= 0.0085 , power is  0.9926
# trying pi= 0.0083 , power is  0.99
# trying pi= 0.0084 , power is  0.991
# trying pi= 0.0042 , power is  0.9053
# trying pi= 0.0021 , power is  0.651
# trying pi= 0.0032 , power is  0.8299
# trying pi= 0.0037 , power is  0.8786
# trying pi= 0.004 , power is  0.8949
# trying pi= 0.0041 , power is  0.899
# trying pi= 0.0021 , power is  0.6578
# trying pi= 0.0032 , power is  0.8289
# trying pi= 0.0027 , power is  0.7625
# trying pi= 0.003 , power is  0.8077
# trying pi= 0.0029 , power is  0.7967
# Running N=10000000, margin=0.05
# trying pi= 0.01 , power is  1.0
# trying pi= 0.005 , power is  1.0
# trying pi= 0.0025 , power is  0.9998
# trying pi= 0.0013 , power is  0.991
# trying pi= 0.0006 , power is  0.8808
# trying pi= 0.0009 , power is  0.9579
# trying pi= 0.0011 , power is  0.9791
# trying pi= 0.0012 , power is  0.9865
# trying pi= 0.0006 , power is  0.8773
# trying pi= 0.0009 , power is  0.9624
# trying pi= 0.0008 , power is  0.9446
# trying pi= 0.0007 , power is  0.916
# trying pi= 0.0003 , power is  0.6028
# trying pi= 0.0005 , power is  0.8198
# trying pi= 0.0004 , power is  0.7409
# Running N=10000000, margin=0.1
# trying pi= 0.01 , power is  1.0
# trying pi= 0.005 , power is  1.0
# trying pi= 0.0025 , power is  1.0
# trying pi= 0.0013 , power is  1.0
# trying pi= 0.0006 , power is  0.9998
# trying pi= 0.0003 , power is  0.9872
# trying pi= 0.0004 , power is  0.9971
# trying pi= 0.0002 , power is  0.9397
# trying pi= 0.0001 , power is  0.733
# trying pi= 0.0001 , power is  0.7452
# Running N=10000000, margin=0.2
# trying pi= 0.01 , power is  1.0
# trying pi= 0.005 , power is  1.0
# trying pi= 0.0025 , power is  1.0
# trying pi= 0.0013 , power is  1.0
# trying pi= 0.0006 , power is  1.0
# trying pi= 0.0003 , power is  1.0
# trying pi= 0.0001 , power is  0.9975

# %%
simTable
# Out:
#       Pop size  Margin  p for 80% power  p for 90% power  p for 99% power
# 0     100000.0    0.01           0.5500           0.6200           0.7700
# 1     100000.0    0.02           0.2300           0.3000           0.4600
# 2     100000.0    0.05           0.0500           0.0700           0.1200
# 3     100000.0    0.10           0.0200           0.0200           0.0400
# 4     100000.0    0.20           0.0100           0.0100           0.0100
# 5    1000000.0    0.01           0.1040           0.1420           0.2420
# 6    1000000.0    0.02           0.0290           0.0400           0.0750
# 7    1000000.0    0.05           0.0050           0.0070           0.0130
# 8    1000000.0    0.10           0.0020           0.0020           0.0040
# 9    1000000.0    0.20           0.0010           0.0010           0.0010
# 10  10000000.0    0.01           0.0115           0.0166           0.0311
# 11  10000000.0    0.02           0.0030           0.0042           0.0084
# 12  10000000.0    0.05           0.0005           0.0007           0.0013
# 13  10000000.0    0.10           0.0002           0.0002           0.0004
# 14  10000000.0    0.20           0.0001           0.0001           0.0001
